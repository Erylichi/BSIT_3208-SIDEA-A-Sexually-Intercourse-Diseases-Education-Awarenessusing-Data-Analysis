# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Total_Reported_Cases_form 2015-2021

# %%
dataset = pd.read_csv(r"C:\Users\user\Documents\HIV-AIDS Registry Reports in Philippines 2015-2021.csv")
display(dataset.iloc[0:,0:11])
# Out:
#            DemoGraphic Data  Total Reported Cases Asymptomatic Cases  \
# 0              2015 January                   536                475
# 1             2015 February                   646                603
# 2                2015 March                   667                643
# 3                2015 April                   560                524
# 4                  2015 May                   748                707
# ..                      ...                   ...                ...
# 87             2021 October                  1136                  -
# 88            2021 November                  1268                  -
# 89            2021 December                   993                  -
# 90       Total of Year 2021                 12341                  -
# 91       TOTAL OF 2015-2021                 72800                  -
#
#    AIDS_Cases No. of Male No. of Female Less_than_15 y/o 15-24  y/o 25-34 y/o  \
# ...

# %% [markdown]
# ### Total Reported Deaths from 2015-2021

# %%
dataset = pd.read_csv(r"C:\Users\user\Documents\HIV-AIDS Registry Reports in Philippines 2015-2021.csv")
display(dataset.iloc[0:91,[1,11,12,13]])
# Out:
#     Total Reported Cases Reported Deaths No. of male Deaths  \
# 0                    536              14                 13
# 1                    646              17                 15
# 2                    667              18                 17
# 3                    560              16                 13
# 4                    748              29                 28
# ..                   ...             ...                ...
# 86                   981             106                  -
# 87                  1136              82                  -
# 88                  1268              92                  -
# 89                   993              50                  -
# 90                 12341             893                  -
#
#    No. of Female Deaths
# 0                     1
# 1                     2
# 2                     1
# 3                     3
# 4                     1
# ..                  ...
# 86                    -
# 87                    -
# ...

# %% [markdown]
# ### Type of Transmission

# %%
dataset = pd.read_csv(r"C:\Users\user\Documents\HIV-AIDS Registry Reports in Philippines 2015-2021.csv")
display(dataset.iloc[0:91,[1,14,15,16,17,18,19]])
# Out:
#     Total Reported Cases Sexual Contact Blood/Blood Products  \
# 0                    536            534                    0
# 1                    646            586                    0
# 2                    667            630                    0
# 3                    560            547                    0
# 4                    748            860                    0
# ..                   ...            ...                  ...
# 86                   981            981                    0
# 87                  1136           1136                    0
# 88                  1268           1268                    0
# 89                   993            993                    0
# 90                 12341          12341                    0
#
#    Sharing of Needles Needle Prick Injury Mother-to-child No Data Available
# 0                   2                   0               0                 0
# 1                  58                   0               2                 0
# ...

# %% [markdown]
# ### Percentage of Diagnosed Cases by Region

# %%
dataset = pd.read_csv(r"C:\Users\user\Documents\Diagnosed Cases by Region (2015-2021).csv")
display (dataset)
# Out:
#       REGIONS Year 2015(%) Year 2016(%) Year 2017(%) Year 2018(%)  \
# 0         NCR          15%          36%          35%          37%
# 1    Region 1           2%           3%           4%           3%
# 2    Region 2           1%           1%           2%           1%
# 3    Region 3          10%          10%          11%          11%
# 4   Region 4A          15%          18%          15%          17%
# 5   Region 4B           2%           2%           1%           1%
# 6    Region 5           1%           1%           3%           2%
# 7    Region 6           6%           3%           7%           7%
# 8    Region 7           7%           8%           7%           8%
# 9    Region 8           1%           1%           2%           1%
# 10   Region 9           2%           2%           1%           2%
# 11  Region 10           2%           2%           3%           3%
# 12  Region 11           8%           6%           4%           3%
# ...
